# %% [markdown]
# ### Cypress "Selector Playground" Feature
#
# - This feature is used to identify the web elements using Cypress Test Runner.
#
# - **Open the Selector Playground:** Launch the Cypress Test Runner. Within the Test Runner, locate and click the "Open Selector Playground" button, typically **positioned near the URL bar at the top**.
#
#   ![image.png](attachment:34ecf6c1-ea18-4fe3-8a98-54fae0814c05.png)
#
# - This is the example.
#
#   > cy.get('[data-id="41189"] > .dynamic-link')

# %% [markdown]
# ### Running Xpath based programs in Cypress
#
# - XPath is not directly supported in Cypress.
#
# - To run XPath based code, first install  ```cypress-xpath``` tool
#
# - Use the below command to install  ```cypress-xpath``` tool
#
# > ```npm install -D cypress-xpath```
#
# - Then use this line first in the XPath based code
#
# > ```require('cypress-xpath')```

# %% [markdown]
# Example1:
# - Browse this URL https://www.letskodeit.com/courses using chrome browser
#
# - Then right click on the control (for example "Search" box) and select "inspect" option
#
# ![image.png](attachment:e7b60461-d049-482f-9362-07226759a7e9.png)
#
# - Then you can identify properties like id and tag and use similar line in your code:
#
# > ```cy.xpath('//input[@id="search"]').type('Test')```

# %% [markdown]
# Example2:
# - Browse this URL https://www.letskodeit.com/courses using chrome browser
#
# - Then type "Test" in  "Search" box, click. Select "inspect" option
#
# > ```cy.xpath('//div[@id="course-list"]').xpath('./div').should('have.length', 6)```
# <table style="text-align: left; margin-left: 0;">
#   <thead>
#     <tr>
#       <th>Part</th>
#       <th>Purpose</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><code>cy.xpath('//div[@id="course-list"]')</code></td>
#       <td>Selects element by ID with XPath</td>
#     </tr>
#     <tr>
#       <td><code>.xpath('./div')</code></td>
#       <td>Selects immediate child &lt;div&gt; elements</td>
#     </tr>
#     <tr>
#       <td><code>.should('have.length', 6)</code></td>
#       <td>Asserts exactly 6 child div elements</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# | Part	                                    | Purpose                                |
# |-------------------------------------------|----------------------------------------|
# |```cy.xpath('//div[@id="course-list"]')``` | Selects element by ID with XPath       |
# |```.xpath('./div')```	                    | Selects immediate child <div> elements |
# |```.should('have.length', 6)```            | Asserts exactly 6 child div elements   |
